# %% [markdown]
# # Hospital HeartDisease

# %%
# Understanding the Dataset and get domeain knowlage
data.head(10)
# Out:
#    Age Sex ChestPainType  RestingBP  Cholesterol  FastingBS RestingECG  MaxHR  \
# 0   40   M           ATA        140          289          0     Normal    172
# 1   49   F           NAP        160          180          0     Normal    156
# 2   37   M           ATA        130          283          0         ST     98
# 3   48   F           ASY        138          214          0     Normal    108
# 4   54   M           NAP        150          195          0     Normal    122
# 5   39   M           NAP        120          339          0     Normal    170
# 6   45   F           ATA        130          237          0     Normal    170
# 7   54   M           ATA        110          208          0     Normal    142
# 8   37   M           ASY        140          207          0     Normal    130
# 9   48   F           ATA        120          284          0     Normal    120
#
#   ExerciseAngina  Oldpeak ST_Slope  HeartDisease
# 0              N      0.0       Up             0
# ...

# %%
# checking the shape of data frame
data.shape
# Out:
# (918, 12)

# %%
# create a dummy data copy
df=data.copy()

# %%
# find duplicate values from data
df.duplicated().sum()
# Out:
# 0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 918 entries, 0 to 917
# Data columns (total 12 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Age             918 non-null    int64
#  1   Sex             918 non-null    object
#  2   ChestPainType   918 non-null    object
#  3   RestingBP       918 non-null    int64
#  4   Cholesterol     918 non-null    int64
#  5   FastingBS       918 non-null    int64
#  6   RestingECG      918 non-null    object
#  7   MaxHR           918 non-null    int64
#  8   ExerciseAngina  918 non-null    object
#  9   Oldpeak         918 non-null    float64
#  10  ST_Slope        918 non-null    object
#  11  HeartDisease    918 non-null    int64
# dtypes: float64(1), int64(6), object(5)
# memory usage: 86.2+ KB

# %%
# finding na value from dataframe
df.isna().sum()
# Out:
# Age               0
# Sex               0
# ChestPainType     0
# RestingBP         0
# Cholesterol       0
# FastingBS         0
# RestingECG        0
# MaxHR             0
# ExerciseAngina    0
# Oldpeak           0
# ST_Slope          0
# HeartDisease      0
# dtype: int64

# %%
# describe dataframe and show one by one columne mean,std,min,max,50%,75%
df.describe()
# Out:
#               Age   RestingBP  Cholesterol   FastingBS       MaxHR  \
# count  918.000000  918.000000   918.000000  918.000000  918.000000
# mean    53.510893  132.396514   198.799564    0.233115  136.809368
# std      9.432617   18.514154   109.384145    0.423046   25.460334
# min     28.000000    0.000000     0.000000    0.000000   60.000000
# 25%     47.000000  120.000000   173.250000    0.000000  120.000000
# 50%     54.000000  130.000000   223.000000    0.000000  138.000000
# 75%     60.000000  140.000000   267.000000    0.000000  156.000000
# max     77.000000  200.000000   603.000000    1.000000  202.000000
#
#           Oldpeak  HeartDisease
# count  918.000000    918.000000
# mean     0.887364      0.553377
# std      1.066570      0.497414
# min     -2.600000      0.000000
# 25%      0.000000      0.000000
# 50%      0.600000      1.000000
# 75%      1.500000      1.000000
# max      6.200000      1.000000

# %%
# rename of column Bp
df.rename(columns={"RestingBP":"Bp"},inplace=True)

# %%
# finding incorrect values by using groupby,unique and value_counts function and undastanding all column
df.groupby("ChestPainType").sum("Sex")
# Out:
#                  Age     Bp  Cholesterol  FastingBS  MaxHR  Oldpeak  \
# ChestPainType
# ASY            27260  66082        92576        141  63725    576.7
# ATA             8519  22598        40317         19  25986     53.2
# NAP            10822  26585        40080         41  29077    137.0
# TA              2522   6275         9525         13   6803     47.7
#
#                HeartDisease
# ChestPainType
# ASY                     392
# ATA                      24
# NAP                      72
# TA                       20

# %%
df.groupby("Sex").sum("Age")
# Out:
#        Age     Bp  Cholesterol  FastingBS  MaxHR  Oldpeak  HeartDisease
# Sex
# F    10131  25517        46551         26  28205    129.1            50
# M    38992  96023       135947        188  97386    685.5           458

# %%
df["ChestPainType"].unique()
# Out:
# array(['ATA', 'NAP', 'ASY', 'TA'], dtype=object)

# %%
df["ChestPainType"].value_counts()
# Out:
# ASY    496
# NAP    203
# ATA    173
# TA      46
# Name: ChestPainType, dtype: int64

# %%
df["Bp"].unique()
# Out:
# array([140, 160, 130, 138, 150, 120, 110, 136, 115, 100, 124, 113, 125,
#        145, 112, 132, 118, 170, 142, 190, 135, 180, 108, 155, 128, 106,
#         92, 200, 122,  98, 105, 133,  95,  80, 137, 185, 165, 126, 152,
#        116,   0, 144, 154, 134, 104, 139, 131, 141, 178, 146, 158, 123,
#        102,  96, 143, 172, 156, 114, 127, 101, 174,  94, 148, 117, 192,
#        129, 164], dtype=int64)

# %%
df["Bp"].value_counts()
# Out:
# 120    132
# 130    118
# 140    107
# 110     58
# 150     55
#       ...
# 185      1
# 98       1
# 92       1
# 113      1
# 164      1
# Name: Bp, Length: 67, dtype: int64

# %%
df["Cholesterol"].unique()
# Out:
# array([289, 180, 283, 214, 195, 339, 237, 208, 207, 284, 211, 164, 204,
#        234, 273, 196, 201, 248, 267, 223, 184, 288, 215, 209, 260, 468,
#        188, 518, 167, 224, 172, 186, 254, 306, 250, 177, 227, 230, 294,
#        264, 259, 175, 318, 216, 340, 233, 205, 245, 194, 270, 213, 365,
#        342, 253, 277, 202, 297, 225, 246, 412, 265, 182, 218, 268, 163,
#        529, 100, 206, 238, 139, 263, 291, 229, 307, 210, 329, 147,  85,
#        269, 275, 179, 392, 466, 129, 241, 255, 276, 282, 338, 160, 156,
#        272, 240, 393, 161, 228, 292, 388, 166, 247, 331, 341, 243, 279,
#        198, 249, 168, 603, 159, 190, 185, 290, 212, 231, 222, 235, 320,
#        187, 266, 287, 404, 312, 251, 328, 285, 280, 192, 193, 308, 219,
#        257, 132, 226, 217, 303, 298, 256, 117, 295, 173, 315, 281, 309,
#        200, 336, 355, 326, 171, 491, 271, 274, 394, 221, 126, 305, 220,
#        242, 347, 344, 358, 169, 181,   0, 236, 203, 153, 316, 311, 252,
# ...

# %%
df["FastingBS"].unique()
# Out:
# array([0, 1], dtype=int64)

# %%
df["FastingBS"].value_counts()
# Out:
# 0    704
# 1    214
# Name: FastingBS, dtype: int64

# %%
df.groupby("FastingBS").sum("ChestPainType")
# Out:
#              Age     Bp  Cholesterol  MaxHR  Oldpeak  HeartDisease
# FastingBS
# 0          36947  92703       151029  97612    602.9           338
# 1          12176  28837        31469  27979    211.7           170

# %%
df["RestingECG"].value_counts()
# Out:
# Normal    552
# LVH       188
# ST        178
# Name: RestingECG, dtype: int64

# %%
df["RestingECG"].unique()
# Out:
# array(['Normal', 'ST', 'LVH'], dtype=object)

# %%
df.groupby("Bp").sum("RestingECG")
# Out:
#      Age  Cholesterol  FastingBS  MaxHR  Oldpeak  HeartDisease
# Bp
# 0     55            0          0    155      1.5             1
# 80    53            0          0    141      2.0             0
# 92    38          117          0    134      2.5             1
# 94    90          426          0    333      0.0             0
# 95   296            0          6    806      5.5             6
# ..   ...          ...        ...    ...      ...           ...
# 180  676         3024          3   1587     12.1             6
# 185   63            0          0     98      0.0             1
# 190  100          528          1    256      2.0             1
# 192   54          283          0    195      0.0             1
# 200  235          486          2    485      7.0             4
#
# [67 rows x 6 columns]

# %%
df["MaxHR"].unique()
# Out:
# array([172, 156,  98, 108, 122, 170, 142, 130, 120,  99, 145, 140, 137,
#        150, 166, 165, 125, 160, 164, 138, 178, 112, 118, 127, 114, 154,
#        155,  87, 148, 100, 168, 184, 121, 153, 134,  96, 174, 175, 144,
#         82, 135, 115, 128, 116,  94, 110,  92, 180, 152, 124, 106, 185,
#        139, 190, 146, 158, 132, 176, 119, 188, 162, 105,  90, 136, 167,
#        129, 102, 143, 103,  91, 126,  93, 131, 149, 123, 182, 141,  77,
#        109, 133, 179, 113, 104,  95,  72,  97, 117,  86,  63, 157,  83,
#         60,  70, 163,  67,  78,  84, 111,  80, 107, 161,  69,  88,  73,
#        159, 151, 181, 186, 177, 173, 169, 171, 147,  71, 192, 195, 194,
#        187, 202], dtype=int64)

# %%
df["ExerciseAngina"].unique()
# Out:
# array(['N', 'Y'], dtype=object)

# %%
df["ExerciseAngina"].value_counts()
# Out:
# N    547
# Y    371
# Name: ExerciseAngina, dtype: int64

# %%
df.groupby("ExerciseAngina").sum("sex")
# Out:
#                   Age     Bp  Cholesterol  FastingBS  MaxHR  Oldpeak  \
# ExerciseAngina
# N               28354  71128       110426        116  79081    289.1
# Y               20769  50412        72072         98  46510    525.5
#
#                 HeartDisease
# ExerciseAngina
# N                        192
# Y                        316

# %%
df["Oldpeak"].unique()
# Out:
# array([ 0. ,  1. ,  1.5,  2. ,  3. ,  4. ,  0.5,  2.5,  5. ,  0.8,  0.7,
#         1.4,  2.1,  0.4,  0.2,  1.7,  2.2,  0.1,  1.6,  1.3,  0.3,  1.8,
#         2.6, -0.9,  2.8, -2.6, -1.5, -0.1,  0.9,  1.1,  2.4, -1. , -1.1,
#        -0.7, -0.8,  3.7,  1.2, -0.5, -2. ,  1.9,  3.5,  0.6,  3.1,  2.3,
#         3.4,  3.6,  4.2,  3.2,  5.6,  3.8,  2.9,  6.2,  4.4])

# %%
df["ST_Slope"].unique()
# Out:
# array(['Up', 'Flat', 'Down'], dtype=object)

# %%
df["ST_Slope"].value_counts()
# Out:
# Flat    460
# Up      395
# Down     63
# Name: ST_Slope, dtype: int64

# %%
df["HeartDisease"].value_counts()
# Out:
# 1    508
# 0    410
# Name: HeartDisease, dtype: int64

# %%
df["HeartDisease"].unique()
# Out:
# array([0, 1], dtype=int64)

# %%
# drop unwanted column from dataframe
df.drop(columns=["Oldpeak"],inplace=True)
df.drop("MaxHR",axis=1,inplace=True)

# %%
# show one time agein dataframe shape
df.shape
# Out:
# (918, 10)

# %% [markdown]
# # Find Outlier

# %%
# find outliers from data by one by one column using boxplot
df.plot.box()
# Out:
# <Axes: >

# %%
plt.boxplot(df["Bp"])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x18c82c252d0>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x18c82c26b10>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x18c82c24750>],
#  'medians': [<matplotlib.lines.Line2D at 0x18c82c341d0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x18c81fdcc10>],
#  'means': []}

# %%
df[df["Bp"]>df["Bp"].quantile(0.98)]
# Out:
#      Age Sex ChestPainType   Bp  Cholesterol  FastingBS RestingECG  \
# 109   39   M           ATA  190          241          0     Normal
# 241   54   M           ASY  200          198          0     Normal
# 365   64   F           ASY  200            0          0     Normal
# 372   63   M           ASY  185            0          0     Normal
# 399   61   M           NAP  200            0          1         ST
# 592   61   M           ASY  190          287          1        LVH
# 732   56   F           ASY  200          288          1        LVH
# 759   54   M           ATA  192          283          0        LVH
#
#     ExerciseAngina ST_Slope  HeartDisease
# 109              N       Up             0
# 241              Y     Flat             1
# 365              Y     Flat             1
# 372              Y       Up             1
# 399              N     Flat             1
# 592              Y     Down             1
# 732              Y     Down             1
# ...

# %%
df=df[df["Bp"]<174]

# %%
plt.boxplot(df["Bp"])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x18c82c70e50>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x18c82ca2390>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x18c82c93f90>],
#  'medians': [<matplotlib.lines.Line2D at 0x18c82ca3a50>],
#  'fliers': [<matplotlib.lines.Line2D at 0x18c82c93710>],
#  'means': []}

# %%
df[df["Bp"]>df["Bp"].quantile(0.99)]
# Out:
#      Age Sex ChestPainType   Bp  Cholesterol  FastingBS RestingECG  \
# 550   55   M           ASY  172          260          0     Normal
# 880   52   M           NAP  172          199          1     Normal
#
#     ExerciseAngina ST_Slope  HeartDisease
# 550              N     Flat             1
# 880              N       Up             0

# %%
df=df[df["Bp"]!=172]

# %%
plt.boxplot(df["Bp"])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x18c820802d0>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x18c820818d0>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x18c82073690>],
#  'medians': [<matplotlib.lines.Line2D at 0x18c82082e50>],
#  'fliers': [<matplotlib.lines.Line2D at 0x18c82073490>],
#  'means': []}

# %%
df.plot.box()
# Out:
# <Axes: >

# %%
df[df["Cholesterol"]>df["Cholesterol"].quantile(0.99)]
# Out:
#      Age Sex ChestPainType   Bp  Cholesterol  FastingBS RestingECG  \
# 28    53   F           ATA  113          468          0     Normal
# 30    53   M           NAP  145          518          0     Normal
# 76    32   M           ASY  118          529          0     Normal
# 103   40   M           ASY  120          466          1     Normal
# 149   54   M           ASY  130          603          1     Normal
# 250   44   M           ASY  135          491          0     Normal
# 496   58   M           ASY  132          458          1     Normal
# 616   67   F           NAP  115          564          0        LVH
# 667   65   F           NAP  140          417          1        LVH
#
#     ExerciseAngina ST_Slope  HeartDisease
# 28               N       Up             0
# 30               N     Flat             1
# 76               N     Flat             1
# 103              Y     Flat             1
# 149              Y     Flat             1
# ...

# %%
df=df[df["Cholesterol"]<384]

# %%
plt.boxplot(df["Cholesterol"])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x18c82d49b10>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x18c82d4af10>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x18c82d49210>],
#  'medians': [<matplotlib.lines.Line2D at 0x18c82d58450>],
#  'fliers': [<matplotlib.lines.Line2D at 0x18c82d49ad0>],
#  'means': []}

# %%
df=df[df['Cholesterol']!=369]

# %%
plt.boxplot(df["Cholesterol"])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x18c82db9510>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x18c82dba190>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x18c82db88d0>],
#  'medians': [<matplotlib.lines.Line2D at 0x18c82dbb610>],
#  'fliers': [<matplotlib.lines.Line2D at 0x18c82dc4090>],
#  'means': []}

# %%
df.plot.box()
# Out:
# <Axes: >

# %% [markdown]
# # Data Visualization

# %%
sns.lineplot(data=df,y="Sex",x="Age")
# Out:
# <Axes: xlabel='Age', ylabel='Sex'>

# %%
sns.histplot(data=df,x="Bp",bins=15)
# Out:
# <Axes: xlabel='Bp', ylabel='Count'>

# %%
sns.displot(data=df,x="Bp",y="Sex")

# %%
sns.catplot(data=df,x="Bp",y="RestingECG")

# %%
sns.boxplot(data=df,x="Age",y="ExerciseAngina")
# Out:
# <Axes: xlabel='Age', ylabel='ExerciseAngina'>

# %%
sns.countplot(data=df,x="RestingECG")
# Out:
# <Axes: xlabel='RestingECG', ylabel='count'>

# %%
# using by realtional plots
sns.relplot(data=df,x="Age",y="Bp",hue="Sex")

# %%
sns.scatterplot(data=df,x="Cholesterol",y="Age",hue="Sex")
# Out:
# <Axes: xlabel='Cholesterol', ylabel='Age'>

# %%
plt.pie(df["HeartDisease"].value_counts(),labels=df["HeartDisease"].unique(),autopct='%1.1f%%', startangle=140)
plt.show()

# %%
# don't use by sampling trick becouse target column is normal distrubeted
df["HeartDisease"].value_counts()
# Out:
# 1    479
# 0    393
# Name: HeartDisease, dtype: int64

# %%
# Import label encoder for converting categorical columns into numeric values
# from sklearn.preprocessing import LabelEncoder

# %%
label_encoder=LabelEncoder()

# %%
df["ST_Slope"]=label_encoder.fit_transform(df["ST_Slope"])
df["Sex"]=label_encoder.fit_transform(df["Sex"])
df["ExerciseAngina"]=label_encoder.fit_transform(df["ExerciseAngina"])
df["RestingECG"]=label_encoder.fit_transform(df["RestingECG"])
df["ChestPainType"]=label_encoder.fit_transform(df["ChestPainType"])

# %%
# Import standard scalar to standardize values of dataframe
# from sklearn.preprocessing import StandardScaler

# %%
scaler=StandardScaler()

# %%
standardize=scaler.fit_transform(df)

# %%
x=df.drop("HeartDisease",axis=1)
y=df["HeartDisease"]

# %%
# split the data into train,test,split
# from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,train_size=0.75,random_state=25)

# %% [markdown]
# # model fitting in machine learning

# %%
# from sklearn.linear_model import LogisticRegression

# %%
model1=LogisticRegression()

# %%
model1.fit(x_train,y_train)
# Out:
# LogisticRegression()

# %%
test_y_pred=model1.predict(x_test)
train_y_pred=model1.predict(x_train)

# %%
# from sklearn.metrics import accuracy_score,classification_report,confusion_matrix

# %%
accuracy_score(test_y_pred,y_test)
# Out:
# 0.8256880733944955

# %%
accuracy_score(train_y_pred,y_train)
# Out:
# 0.8577981651376146

# %%
# from sklearn.ensemble import RandomForestClassifier

# %%
model=RandomForestClassifier(n_estimators=40,max_depth=2)

# %%
model.fit(x_train,y_train)
# Out:
# RandomForestClassifier(max_depth=2, n_estimators=40)

# %%
tr_y_pred=model.predict(x_train)
te_Y_pred=model.predict(x_test)

# %%
accuracy_score(tr_y_pred,y_train)
# Out:
# 0.8807339449541285

# %%
accuracy_score(te_Y_pred,y_test)
# Out:
# 0.8394495412844036

# %%
# from sklearn.tree import DecisionTreeClassifier

# %%
model2=DecisionTreeClassifier()

# %%
model2.fit(x_train,y_train)
# Out:
# DecisionTreeClassifier()

# %%
tr_pred=model2.predict(x_train)
te_pred=model2.predict(x_test)

# %%
accuracy_score(tr_pred,y_train)
# Out:
# 1.0

# %%
accuracy_score(te_pred,y_test)
# Out:
# 0.7981651376146789

# %%
# from sklearn import tree

# %%
tree.plot_tree(model2)
plt.show()

# %%
# what is post proning methoed ....?

# %%
model3=DecisionTreeClassifier(max_depth=2,max_features=2)

# %%
model3.fit(x_train,y_train)
# Out:
# DecisionTreeClassifier(max_depth=2, max_features=2)

# %%
tr_y_pr=model3.predict(x_train)
te_y_pr=model3.predict(x_test)

# %%
accuracy_score(tr_y_pr,y_train)
# Out:
# 0.8195718654434251

# %%
accuracy_score(te_y_pr,y_test)
# Out:
# 0.7935779816513762

# %%
tree.plot_tree(model3)
plt.show()
